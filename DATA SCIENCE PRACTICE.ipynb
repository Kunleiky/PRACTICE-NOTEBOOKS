# %%
notebook inline

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
import pandas as pd
import numpy as np

# %%
heart=pd.read_csv(r"C:\Users\MY PC\Desktop\TO PHONE\Heart.csv")

# %%
pd.set_option('display.max_columns',200)

# %%
heart.head()
# Out:
#    Id  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0   1   63    1       typical     145   233    1        2    150      0
# 1   2   67    1  asymptomatic     160   286    0        2    108      1
# 2   3   67    1  asymptomatic     120   229    0        2    129      1
# 3   4   37    1    nonanginal     130   250    0        0    187      0
# 4   5   41    0    nontypical     130   204    0        2    172      0
#
#    Oldpeak  Slope   Ca        Thal  AHD
# 0      2.3      3  0.0       fixed   No
# 1      1.5      2  3.0      normal  Yes
# 2      2.6      2  2.0  reversable  Yes
# 3      3.5      3  0.0      normal   No
# 4      1.4      1  0.0      normal   No

# %%
sns.countplot(y='AHD',data=heart)

# %%
heart["AHD"].value_counts()
# Out:
# No     164
# Yes    139
# Name: AHD, dtype: int64

# %%
heart["AHD"].value_counts().plot(kind='bar')

# %%
pd.plotting.scatter_matrix(heart, diagonal='kde', alpha=0.95,figsize=(12,12));

# %%
heartAHDabove60= heart[heart.AHD=="Yes"]

# %%
heartAHDabove60.head()
# Out:
#    Id  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 1   2   67    1  asymptomatic     160   286    0        2    108      1
# 2   3   67    1  asymptomatic     120   229    0        2    129      1
# 6   7   62    0  asymptomatic     140   268    0        2    160      0
# 8   9   63    1  asymptomatic     130   254    0        2    147      0
# 9  10   53    1  asymptomatic     140   203    1        2    155      1
#
#    Oldpeak  Slope   Ca        Thal  AHD
# 1      1.5      2  3.0      normal  Yes
# 2      2.6      2  2.0  reversable  Yes
# 6      3.6      3  2.0      normal  Yes
# 8      1.4      2  1.0  reversable  Yes
# 9      3.1      3  0.0  reversable  Yes

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(heart["Age"],color="#61d199",vertical=False )
plt.savefig(r"C:\Users\MY PC\Desktop\kde.png",format="png", dpi=220)

# %%
# !jt -t onedork

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
autodf= pd.read_csv(r"C:\Users\MY PC\Desktop\TO PHONE\Auto.csv", usecols=["mpg","cylinders","year","origin", "name"])

# %%
pd.set_option("display.max_columns", 100)

# %%
autodf.isnull()
# Out:
#        mpg  cylinders   year  origin   name
# 0    False      False  False   False  False
# 1    False      False  False   False  False
# 2    False      False  False   False  False
# 3    False      False  False   False  False
# 4    False      False  False   False  False
# ..     ...        ...    ...     ...    ...
# 392  False      False  False   False  False
# 393  False      False  False   False  False
# 394  False      False  False   False  False
# 395  False      False  False   False  False
# 396  False      False  False   False  False
#
# [397 rows x 5 columns]

# %%
autodf.head(85)
# Out:
#      mpg  cylinders  year  origin                         name
# 0   18.0          8    70       1    chevrolet chevelle malibu
# 1   15.0          8    70       1            buick skylark 320
# 2   18.0          8    70       1           plymouth satellite
# 3   16.0          8    70       1                amc rebel sst
# 4   17.0          8    70       1                  ford torino
# ..   ...        ...   ...     ...                          ...
# 80  22.0          4    72       1              ford pinto (sw)
# 81  28.0          4    72       3              datsun 510 (sw)
# 82  23.0          4    72       3  toyouta corona mark ii (sw)
# 83  28.0          4    72       1              dodge colt (sw)
# 84  27.0          4    72       3     toyota corolla 1600 (sw)
#
# [85 rows x 5 columns]

# %%
sns.set_style("darkgrid")

# %%
sns.swarmplot( x= "origin",y="mpg", data=autodf,hue="origin",color="m")
plt.savefig(r"C:\Users\MY PC\Desktop\swarm.png",format="png", dpi=220, orientation='portrait')

# %%
plt.savefig(r"C:\Users\MY PC\Desktop\PLAYLISTS\MY CHARTS\violinmpg.png", format= "png", dpi=200)

# %%
sns.violinplot(x="origin", y="mpg",data=autodf,)

# %%
pd.plotting.scatter_matrix(autodf, diagonal='kde', alpha=0.95,figsize=(12,12))
plt.savefig(r"C:\Users\MY PC\Desktop\scatter_matrix.png",format="png", dpi=220)

# %%
sampl_5=autodf.sample(5)

sampl_5.isnull().values.any()
# Out:
# False

# %%
print(sampl_5)
# Out:
#       mpg  cylinders  year  origin                name
# 253  20.5          6    78       1    chevrolet malibu
# 92   13.0          8    73       1            ford ltd
# 313  28.0          4    80       1  chevrolet citation
# 176  19.0          6    75       1           amc pacer
# 170  23.0          4    75       1       pontiac astro

# %%
fortune= pd.read_csv(r'C:\Users\MY PC\Desktop\TO PHONE\FORTUNE_500_2017.csv')

# %%
fortune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         500 non-null    int64
#  1   Title        500 non-null    object
#  2   Website      500 non-null    object
#  3   Employees    500 non-null    int64
#  4   Sector       500 non-null    object
#  5   Industry     500 non-null    object
#  6   Hqlocation   500 non-null    object
#  7   Hqaddr       500 non-null    object
#  8   Hqcity       500 non-null    object
#  9   Hqstate      500 non-null    object
#  10  Hqzip        500 non-null    int64
#  11  Hqtel        500 non-null    object
#  12  Ceo          500 non-null    object
#  13  Ceo-title    500 non-null    object
#  14  Address      500 non-null    object
#  15  Ticker       500 non-null    object
#  16  Fullname     500 non-null    object
#  17  Revenues     500 non-null    int64
# ...

# %%
pd.set_option("display.max_rows", 100)

# %%
fortune
# Out:
#      Rank               Title                           Website  Employees  \
# 0       1             Walmart            http://www.walmart.com    2300000
# 1       2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2       3               Apple              http://www.apple.com     116000
# 3       4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4       5            McKesson           http://www.mckesson.com      68000
# ..    ...                 ...                               ...        ...
# 495   496       Michaels Cos.           http://www.michaels.com      31000
# 496   497       Toll Brothers       http://www.tollbrothers.com       4200
# 497   498               Yahoo              http://www.yahoo.com       8500
# 498   499       Vistra Energy       http://www.vistraenergy.com       4431
# 499   500      ABM Industries                http://www.abm.com     110000
#
# ...

# %%
fortune.style.hide_index()
# Out:
# <style  type="text/css" >
# ...

# %%
fortune.query('Profits<500')
# Out:
#      Rank                      Title                          Website  \
# 18     19                    Chevron           http://www.chevron.com
# 32     33  State Farm Insurance Cos.         http://www.statefarm.com
# 40     41          Dell Technologies  http://www.delltechnologies.com
# 48     49            Albertsons Cos.        http://www.albertsons.com
# 54     55                        AIG               http://www.aig.com
# ..    ...                        ...                              ...
# 495   496              Michaels Cos.          http://www.michaels.com
# 496   497              Toll Brothers      http://www.tollbrothers.com
# 497   498                      Yahoo             http://www.yahoo.com
# 498   499              Vistra Energy      http://www.vistraenergy.com
# 499   500             ABM Industries               http://www.abm.com
#
#      Employees                      Sector  \
# 18       55200                      Energy
# ...

# %%
fortune.describe().round(4)
# Out:
#            Rank     Employees       Hqzip     Revenues  Revchange     Profits  \
# count  500.0000  5.000000e+02    500.0000     500.0000   500.0000    500.0000
# mean   250.4920  5.635013e+04  46791.7140   24111.7480     3.7580   1779.4798
# std    144.4774  1.234520e+05  30160.3848   38337.3533    19.9675   3937.5587
# min      1.0000  8.300000e+01   1104.0000    5145.0000   -57.5000  -6177.0000
# 25%    125.7500  1.190000e+04  19099.0000    7245.0000    -3.8250    235.7250
# 50%    250.5000  2.500000e+04  46244.5000   11384.0000     1.9000    683.6000
# 75%    375.2500  5.682525e+04  75045.0000   22605.2500     7.3250   1770.7750
# max    500.0000  2.300000e+06  98188.0000  485873.0000   197.3000  45687.0000
#
#              Assets  Totshequity
# count  5.000000e+02     500.0000
# mean   8.038934e+04   13640.1470
# std    2.704257e+05   30523.1538
# min    4.370000e+02  -12688.0000
# 25%    8.436500e+03    1997.5000
# 50%    1.932450e+04    4981.0000
# ...

# %%
top5= fortune[fortune.Rank<=5]

# %%
top5
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
# ...

# %%
oddtop5= top5[(top5['Rank']%2)==1]

# %%
oddtop5
# Out:
#    Rank     Title                  Website  Employees       Sector  \
# 0     1   Walmart   http://www.walmart.com    2300000    Retailing
# 2     3     Apple     http://www.apple.com     116000   Technology
# 4     5  McKesson  http://www.mckesson.com      68000  Wholesalers
#
#                       Industry         Hqlocation               Hqaddr  \
# 0        General Merchandisers    Bentonville, AR  702 S.W. Eighth St.
# 2  Computers, Office Equipment      Cupertino, CA      1 Infinite Loop
# 4     Wholesalers: Health Care  San Francisco, CA           1 Post St.
#
#           Hqcity Hqstate  Hqzip         Hqtel                  Ceo  \
# 0    Bentonville      AR  72716  479-273-4000  C. Douglas McMillon
# 2      Cupertino      CA  95014  408-996-1010      Timothy D. Cook
# 4  San Francisco      CA  94104  415-983-8300   John H. Hammergren
#
#                                        Ceo-title  \
# 0  President, Chief Executive Officer & Director
# ...

# %%
top5['Revenues'].describe().round(2)
# Out:
# count         5.00
# mean     264521.40
# std      124289.51
# min      192487.00
# 25%      205004.00
# 50%      215639.00
# 75%      223604.00
# max      485873.00
# Name: Revenues, dtype: float64

# %%
top5corr= top5.corr() #Correlation matrix

# %%
sns.heatmap(top5corr, cmap="coolwarm",cbar=False, annot=True)
plt.savefig(r"C:\Users\MY PC\Desktop\fortunetop5.png",format="png",bbox_inches="tight",dpi=100,orientation="landscape")

# %%
tips =sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_582b238a_cafd_11ea_a1c6_ecb1d7be8d3a" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_582b238a_cafd_11ea_a1c6_ecb1d7be8d3arow0_col0" class="data row0 col0" >16.990000</td>
#                         <td id="T_582b238a_cafd_11ea_a1c6_ecb1d7be8d3arow0_col1" class="data row0 col1" >1.010000</td>
#                         <td id="T_582b238a_cafd_11ea_a1c6_ecb1d7be8d3arow0_col2" class="data row0 col2" >Female</td>
# ...

# %%
tips.head(15).style.highlight_min(color="#ff0000").highlight_max(color="#0000ff")
# Out:
# <style  type="text/css" >
#     #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow0_col1 {
#             background-color:  #ff0000;
#             : ;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow0_col6 {
#             background-color:  #ff0000;
#             : ;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow3_col6 {
#             background-color:  #ff0000;
#             : ;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow4_col6 {
#             : ;
#             background-color:  #0000ff;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow5_col6 {
#             : ;
#             background-color:  #0000ff;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow6_col0 {
#             background-color:  #ff0000;
#             : ;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow6_col6 {
#             background-color:  #ff0000;
#             : ;
#         }    #T_5872afe8_cafd_11ea_af40_ecb1d7be8d3arow7_col6 {
#             : ;
# ...

# %%
sns.boxplot(y=tips["total_bill"],x=tips["smoker"])

# %%
iris=sns.load_dataset("iris")

# %%
iris.head(40)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris.hist("sepal_length", by= "species")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c0412c194952> in <module>
# ----> 1 iris.hist("sepal_length", by= "species")
#
# NameError: name 'iris' is not defined

# %%
iris.hist("sepal_width",xrot=45,yrot=35,figsize=(12,14),by="species")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE6A86ADC8>,
# ...
#       dtype=object)

# %%
sns.boxplot(y=iris["sepal_length"],x=iris["species"])
plt.savefig(r"C:\Users\MY PC\Desktop\iris_sepal.png",format="png", dpi=None,orientation="landscape")

# %%
sns.violinplot(y=iris["sepal_length"],x=iris["species"])

# %%
sns.violinplot(y=iris["petal_length"],x=iris["species"])

# %%
sns.violinplot(y=iris["petal_width"],x=iris["species"])

# %%
sns.violinplot(y=iris["sepal_width"],x=iris["species"])

# %%
import pip

# %%
#I want to install Jupter Notebook extension

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
telecoms=['MTN','9Mobile','Airtel','Glo']
revenue=(376000,6445000,6045000,7036000)
tax=(120000,300000,250000,345000)

# %%
ind=[x for x,_ in enumerate(telecoms)]

# %%
_
# Out:
# Text(0.5, 1, 'Telecom companies revenue and tax in the last fiscal year')

# %%
print(In[18])
# Out:
# _

# %%
plt.bar(ind,revenue,width=0.8,label='revenue',color='blue',bottom=tax)
plt.bar(ind,tax,width=0.8,label='tax',color='red')
plt.xticks(ind,telecoms)
plt.ylabel("value(in million Naira)")
plt.xlabel("Telecom companies")
plt.legend(loc='best')
plt.title('Telecom companies revenue and tax in the last fiscal year')
# Out:
# Text(0.5, 1.0, 'Telecom companies revenue and tax in the last fiscal year')

# %%
import pandas as pd

# %%
kp= pd.ExcelFile(r'C:\Users\MY PC\Desktop\PLAYLISTS\MY FILES\DATA SCIENCE PROJECTS\kp\kp.xlsx')

# %%
kp

# %%
transaction=kp.parse('Transactions')

# %%
transaction.head(50)
# Out:
#     transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                1           2         2950       2017-02-25           0.0
# 1                2           3         3120       2017-05-21           1.0
# 2                3          37          402       2017-10-16           0.0
# 3                4          88         3135       2017-08-31           0.0
# 4                5          78          787       2017-10-01           1.0
# 5                6          25         2339       2017-03-08           1.0
# 6                7          22         1542       2017-04-21           1.0
# 7                8          15         2459       2017-07-15           0.0
# 8                9          67         1305       2017-08-10           0.0
# 9               10          12         3262       2017-08-30           1.0
# 10              11           5         1986       2017-01-17           0.0
# ...

# %%
# !pip install jupyter Nbextensions enable__py__sys-prefix_qgrid
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement Nbextensions (from versions: none)
# ERROR: No matching distribution found for Nbextensions

# %%
transaction.values
# Out:
# array([[1, 2, 2950, ..., 71.49, 53.62, 41245.0],
#        [2, 3, 3120, ..., 2091.47, 388.92, 41701.0],
#        [3, 37, 402, ..., 1793.43, 248.82, 36361.0],
#        ...,
#        [19998, 87, 2284, ..., 1636.9, 44.71, 40410.0],
#        [19999, 6, 2764, ..., 227.88, 136.73, 38216.0],
#        [20000, 11, 1144, ..., 1775.81, 1580.47, 36334.0]], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook
sns.set_style('ticks')

# %%
planets=sns.load_dataset("planets")
cmap=sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax=sns.scatterplot(x="distance",y= "orbital_period",hue="year",size="mass", palette=cmap, sizes=(100,400), data=planets)
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">
